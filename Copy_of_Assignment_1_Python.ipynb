# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshCT/assignment/blob/main/Copy_of_Assignment_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  1. What is a list ?
# * List is data type in the python which is used to store multipal information in a single variable.
# * Lists are created using square bracket.
# * In this list we can store store int. values,string and float values.
# * List values are order,changeable and allow duplicate values.

# %% [markdown]
# 2. What is a Tuple?
# *   Tuple allow to store multipal information in the single variable.
# *   They are ordered,unchangeable and allow duplicate values in set.
# *   Tuples are represented in the round bracket.
# *   tuple items are indexed.

# %% [markdown]
# 3. What is the difference between List and Tuple?
# ![WhatsApp Image 2023-01-29 at 9.49.54 AM.jpeg](data:image/jpeg;base64,...)

# %%
#4.Python Program to find the largest element in the list
List1 = [12,34,99,14,15]
print("largest element in list:",max(List1))
# Out:
# largest element in list: 99

# %%
#5. Python program to interchange first and last elements in a list
def swapList(list):
  start,*middle,end = list
  list= [end,*middle,start]
  return list
newList=[23,12,34,15,82]
print(swapList(newList))
# Out:
# [82, 12, 34, 15, 23]

# %%
#6. Python program to swap two elements in a list
def swapList(list):
 start,*middle,end = list
 list=[start,end,*middle]
 return list
newlist=[12,34,56,23]
print(swapList(newlist))
# Out:
# [12, 23, 34, 56]

# %%
#7. Python program to Reverse a List
list1 = [12,13,14,16]
a=list1[::-1]
print(a)
# Out:
# [16, 14, 13, 12]

# %%
#8. Python program to count occurrences of an element in a list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-ed75a0640e55> in <module>
#       4 lst= [12,14,16,23,45,67,12]
#       5 x=12
# ----> 6 print("occurrences",lst.countx)
#
# AttributeError: 'list' object has no attribute 'countx'

# %%
#9. Python program to find the sum of elements in a list
a=[12,13,12,12,13]
total = sum(a)
print("sum of elements in list",total)
# Out:
# sum of elements in list 62

# %%
#10. Python program to Multiply all numbers in the list
import numpy
a = [10,12,12,10,1]
output= numpy.product(a)
print("final result",output)
# Out:
# final result 14400

# %%
#11. What are the ways to find the length of a list
a= [12,1,3,4,5,6,24]
print(len(a))
print("total numer of elements in given list:")
#or
a=[0,1,2,3,4,5]
counter = 0
for i in a:
  counter +=1
  print(counter)
# Out:
# 7
# total numer of elements in given list:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#12. Python program to find the smallest and largest number in a list (Without
#min-max function)

# %%
#13. Python Program to find the area of a circle
import math
math.pi
r = int(input("mention radius"))
print(math.pi)
area =math.pi*r*r
print("print area of circle:",area)
# Out:
# mention radius10
# 3.141592653589793
# print area of circle: 314.1592653589793

# %%
#14. Take inputs from the user to make a list. Again take one input from the user and search it in the list and delete that element, if found. Iterate over a list using for loop.
a=[12,13,14,15,15]
b=[14,15,56,45,78]
c= list()
for item in b:
  c.append(item)
  for item in a:
        c.append(item)
        
print(c)
# Out:
# [14, 12, 13, 14, 15, 15, 15, 12, 13, 14, 15, 15, 56, 12, 13, 14, 15, 15, 45, 12, 13, 14, 15, 15, 78, 12, 13, 14, 15, 15]

# %%
 
#15. You are given a list of integer elements. Make a new list that will store a square of elements of the previous list. (With and without list comprehension) 
#Input_list = [2,5,6,12]
#Output_list = [4,25,36,144]
input_list = [2,5,6,12]
result=[ i**2 for i in input_list]
print("square of elements in list",result)
#or
#without use of comprehension
input_list=[2,5,6,12]
def square(input_list):
  ret = []
  for i in input_list:
    ret.append(i ** 2)
  return ret
# Out:
# square of elements in list [4, 25, 36, 144]
